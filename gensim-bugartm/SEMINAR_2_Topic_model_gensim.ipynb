# %%
import gensim
import json
import re
from nltk.tokenize import word_tokenize
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim 

morph = MorphAnalyzer()
# Out:
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\utils.py:1167: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
# ## Домашнее задание

# %% [markdown]
# Основаная задача - **построить хорошую тематическую модель с интерпретируемыми топиками**.
#
# 1) сделайте нормализацию (если pymorphy2 работает долго используйте mystem или попробуйте установить быструю версию - `pip install pymorphy2[fast]`, можно использовать какой-то другой токенизатор);
#
# 2) добавьте нграммы (в тетрадке есть закомменченая ячейка с Phrases);
#
# 3) сделайте хороший словарь (отфильтруйте слишком частотные и редкие слова, попробуйте удалить стоп-слова);
#
# 4) постройте несколько LDA моделей (переберите количество тем, можете поменять eta, alpha, passes), если получаются плохие темы, поработайте дополнительно над предобработкой и словарем;
#
# 5) для самой хорошей модели в отдельной ячейке напечатайте 3 хороших (на ваш вкус) темы;
#
# 6) между словарем и обучением модели добавьте tfidf (`gensim.models.TfidfModel(corpus, id2word=dictionary); corpus = tfidf[corpus]`);
#
# 7) заново обучите LDA c теми же параметрами (параметрами самой лучшей модели, заново перебирать не нужно);
#
# 8) в отдельной ячейке опишите как изменилась модель (приведите несколько тем, которые стали лучше или хуже, или которых раньше вообще не было; можно привести значения перплексии и когерентности для обеих моделей)
#
# 9) проделайте такие же действия для NMF (образец в конце тетрадки), для построения словаря воспользуйтесь возможностями Count или Tfidf Vectorizer (попробуйте другие значение max_features, min_df, max_df, сделайте нграмы через ngram_range, если хватает памяти), попробуйте такие же количества тем
#
# 10) в отдельной ячейки напечатайте таблицу с темами лучшей NMF модели, сравните их с теми, что получились в LDA.
#
# Сохраните тетрадку с экспериментами и положите её на гитхаб, ссылку на неё укажите в форме.
#
# **Оцениваться будут главным образом пункты 5, 8 и 10. (2, 3, 2 баллов соответственно). Чтобы заработать остальные 3 балла, нужно хотя бы немного изменить мой код на промежуточных этапах (добавить что-то, указать другие параметры и т.д). **

# %% [markdown]
# ## Данные

# %%
def remove_tags(text):
    return re.sub(r'<[^>]+>', '', text)

def clean(words):
    clean = [morph.parse(word)[0].normal_form for word in words if len(set(word)) > 1]
    return clean

# %% [markdown]
# Возьмем 4 тыс статьи с Хабра. Это мало для хорошей тематической модели, но иначе у нас просто ничего не обучится за семинар.

# %%
texts = open('habr_texts.txt', encoding='utf-8').read().splitlines()

# %% [markdown]
# В текстах есть тэги. Потрем их. Ещё токенизируем самым простым способом и нормализуем Pymorphy.

# %%
texts = [clean(word_tokenize(text.lower())) for text in texts]

# %%
# для нграммов
from nltk.corpus import stopwords
stop_words = stopwords.words('russian')
stop_words.extend(['что', 'это', 'так', 'вот', 'быть', 'как', 'в', '—', 'к', 'на', 'и', 'с'])
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.44, common_terms=set(stop_words)) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts]
# Out:
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\phrases.py:317: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if all(parameter in getargspec(scoring)[0] for parameter in scoring_parameters):

# %%
p[texts[1]]
# Out:
# ['введение',
#  'выбор',
#  'решение',
#  'рано_или_поздно',
#  'наступать',
#  'такой',
#  'момент',
#  'жизнь',
#  'любой',
#  'сообщество',
#  'форум',
#  'когда',
#  'для',
#  'привлечение_удержание',
#  'человек',
#  'возникать',
#  'острый_необходимость',
#  'использование',
#  'новое',
#  'инструментарий',
#  'такой',
#  'весьма',
#  'эффективный',
#  'инструмент',
#  'являться',
#  'то',
#  'что',
#  'крыться',
#  'за',
#  'модный_ныне',
#  'слово',
#  'геймификация',
#  'то',
#  'есть',
#  'использование',
#  'характерный',
#  'для',
#  'игра',
#  'приём',
#  'подход',
#  'неигровой',
#  'процесс',
#  'по',
#  'привлечение',
#  'вовлечение',
#  'участник',
#  'сообщество',
#  'на',
#  'форум',
#  'создание',
#  'активный',
#  'мощный',
#  'информационный',
#  'поль',
#  'вокруг',
#  'наш',
#  'продукт',
#  'использовать',
#  'наш',
#  'компания',
#  'форумный_движок',
#  'xenforo_настоящее',
#  'время',
#  'являться',
#  'наиболее_популярный',
#  'быстро',
#  'развивающийся',
#  'этот',
#  'движок',
#  'по-умолчание',
#  'иметь',
#  'встроить',
#  'система',
#  'трофей_основать',
#  'на',
#  'собственный',
#  'весьма',
#  'ограниченный',
#  'система',
#  'критерий',
#  'сам',
#  'система',
#  'создание',
#  'трофей',
#  'также',
#  'иметь',
#  'ограниченный',
#  'функционал',
#  'например',
#  'нет',
#  'возможность',
#  'создавать',
#  'трофей',
#  'графический_бейджема',
#  'нет',
#  'возможность',
#  'создавать',
#  'скрытый',
#  'трофей',
#  'т.д',
#  'для',
#  'пример',
#  'привести',
#  'скриншот',
#  'дефолтной',
#  'система',
#  'трофей_xenforo',
#  'для',
#  'трофей_addicted',
#  'присваиваться',
#  'случай',
#  'достижение',
#  '1000',
#  'пост',
#  'определение',
#  'критерий',
#  'для',
#  'это',
#  'трофей',
#  'выглядеть',
#  'так',
#  'таб_award',
#  'this',
#  'trophy',
#  'if',
#  'действительно',
#  'вполне_возможно',
#  'создать',
#  'использовать',
#  'геймификация',
#  'на',
#  'основа',
#  'встроить',
#  'инструментарий',
#  'критерий',
#  'но',
#  'конечный_счёт',
#  'это',
#  'выглядеть',
#  'недостаточно_привлекательно',
#  'современно_критерий',
#  'для',
#  'получение',
#  'трофей',
#  'также',
#  'недостаточно',
#  'движок_xenforo',
#  'хороший',
#  'тем',
#  'что',
#  'он',
#  'иметь',
#  'весьма',
#  'серьёзный',
#  'активный',
#  'сообщество',
#  'иметься',
#  'русскоязычный',
#  'группа',
#  'который',
#  'постоянно',
#  'работать',
#  'над',
#  'он',
#  'улучшение',
#  'создать',
#  'огромный',
#  'база',
#  'всевозможный',
#  'плагин',
#  'стиль',
#  'шаблон',
#  'т._д.',
#  'они',
#  'бывать',
#  'как',
#  'коммерческий',
#  'так',
#  'бесплатный',
#  'существовать',
#  'даже',
#  'отдельный',
#  'компания',
#  'заниматься',
#  'разработка',
#  'продажа',
#  'решение',
#  'для',
#  'xenforo',
#  'например_brivium',
#  'такой',
#  'образ',
#  'потратить',
#  'некоторый',
#  'время',
#  'на',
#  'поиск',
#  'подходящий',
#  'решение',
#  'запрос',
#  'сообщество',
#  'быть',
#  'определить',
#  'хороший',
#  'на',
#  'сегодняшний_день',
#  'решение',
#  'для',
#  'реализация',
#  'продвинуть',
#  'система',
#  'трофей',
#  'достижение',
#  'на',
#  'платформа',
#  'xenforo_связка',
#  'плагин',
#  'master_badge',
#  'cta_criteria',
#  'быть',
#  'опробовать',
#  'другой',
#  'популярный',
#  'решение',
#  'например_brivium',
#  'extra_trophies',
#  'awarded_но_они_функциональность',
#  'быть',
#  'оценить',
#  'как',
#  'недостаточный',
#  'но',
#  'вернуться',
#  'связка',
#  'master_badge',
#  'cta_criteria',
#  'один',
#  'плагин',
#  'представлять',
#  'себя',
#  'платный',
#  '35',
#  'мощный',
#  'решение',
#  'для',
#  'управление',
#  'система',
#  'достижение',
#  'трофей',
#  'два',
#  'плагин',
#  'бесплатный_увеличитель',
#  'количество',
#  'возможный',
#  'критерий',
#  'для',
#  'получение',
#  'трофей',
#  'оба',
#  'плагин',
#  'обновляться',
#  'нечасто_но_2016-ом',
#  'год',
#  'обновление',
#  'выходить',
#  'разработчик',
#  'легко',
#  'просто',
#  'связаться',
#  'либо',
#  'обсуждение',
#  'плагин',
#  'на',
#  'он',
#  'страница',
#  'либо',
#  'приватный_переписке.настройка',
#  'плагин',
#  'master_badge',
#  'разобраться',
#  'подробный',
#  'настройка',
#  'плагин',
#  'master_badge',
#  'один',
#  'таб',
#  'выглядеть',
#  'так',
#  'здесь',
#  'интересный',
#  'опция',
#  'display',
#  'user',
#  "'s_featured",
#  'badges',
#  'in',
#  'member_card',
#  'связать_она_featured',
#  'badges_поле',
#  'ниже',
#  'можно',
#  'задать',
#  'сколько',
#  'трофей',
#  'юзер',
#  'мочь',
#  'отражать',
#  'на',
#  'свой',
#  'memeber_card',
#  'зависимость',
#  'от',
#  'свой',
#  'текущий',
#  'уровень',
#  'например',
#  'для',
#  'достигнутый_10-го',
#  'уровень',
#  'юзер',
#  'мочь',
#  'на',
#  'свой',
#  'member_card',
#  'показать',
#  'заработать',
#  'трофей',
#  'выглядеть',
#  'это',
#  'вот',
#  'так',
#  'следующий',
#  'таб',
#  'настройка',
#  'выглядеть',
#  'так',
#  'тут',
#  'интерес',
#  'представлять',
#  'то',
#  'сколько',
#  'очки',
#  'нужно',
#  'набрать',
#  'до',
#  'достижение',
#  'следующий',
#  'уровень',
#  'points_per',
#  'level',
#  'система',
#  'начисление_очки',
#  'при',
#  'переход',
#  'уровень',
#  'на',
#  'уровень',
#  'выше',
#  'level',
#  'up',
#  'options',
#  'иметься',
#  'даже',
#  'level_calculator',
#  'для',
#  'вычисление',
#  'необходимый',
#  'количество',
#  'очки',
#  'для',
#  'достижение',
#  'тот',
#  'или',
#  'иной',
#  'уровень',
#  'три',
#  'таб',
#  'настройка',
#  'тут',
#  'определяться_месторасположение',
#  'виджет',
#  'прогресс',
#  'progress',
#  'to',
#  'next',
#  'level',
#  'топ',
#  'юзер',
#  'top',
#  'level_сайдбар',
#  'форума.создание',
#  'система',
#  'трофей',
#  'для',
#  'начало',
#  'нужно',
#  'сказать',
#  'что',
#  'master_badge',
#  'определять',
#  'два',
#  'важный',
#  'сущность',
#  'badge_trophy',
#  'badge',
#  'иметь',
#  'собственный',
#  'свойство',
#  'важный',
#  'из',
#  'который',
#  'badge_mode',
#  'мочь',
#  'включать',
#  'себя',
#  'трофей_trophies',
#  'badge_mode',
#  'мочь',
#  'быть',
#  'visible',
#  'весь',
#  'трофей',
#  'входящая_этот_badge',
#  'видный',
#  'step_by',
#  'step',
#  'следующий',
#  'трофей',
#  'быть',
#  'показать',
#  'только',
#  'после',
#  'тот',
#  'как',
#  'предыдущий',
#  'быть',
#  'получить',
#  'hidden_трофей',
#  'быть',
#  'показать',
#  'только',
#  'тогда',
#  'когда',
#  'быть',
#  'получить',
#  'внутри',
#  'badge',
#  'мы',
#  'создавать',
#  'трофей',
#  'хотя',
#  'трофей',
#  'можно',
#  'создавать',
#  'не',
#  'включая',
#  'они',
#  'badge',
#  'окно',
#  'создание',
#  'трофей',
#  'иметься',
#  'три',
#  'таба',
#  'для',
#  'мы',
#  'важный',
#  'один',
#  'два',
#  'на',
#  'первое',
#  'задаваться',
#  'название',
#  'трофей',
#  'он',
#  'ценность_trophy',
#  'points',
#  'он',
#  'описание',
#  'он',
#  'принадлежность_badge',
#  'он',
#  'порядок',
#  'он',
#  'иконка_два_таб',
#  'самый',
#  'важный',
#  'здесь',
#  'задаваться',
#  'критерий',
#  'получение',
#  'трофей',
#  'благодаря',
#  'уже',
#  'упомянуть',
#  'плагин',
#  'cta_criteria',
#  'количество',
#  'этот',
#  'критерий',
#  'значительно',
#  'увеличить',
#  'отличие_от_умолчательный',
#  'система',
#  'трофей_xenforo',
#  'тут',
#  'не',
#  'влезть',
#  'весь',
#  'возможный',
#  'критерий',
#  'включить',
#  'только',
#  'один',
#  'достижение',
#  '100',
#  'лайковый',
#  'критерий',
#  'для',
#  'трофей_можно_комбинировать',
#  'что',
#  'позволять',
#  'создавать',
#  'всевозможный_экзотический',
#  'редкий',
#  'трофей',
#  'итог',
#  'формироваться',
#  'определённый',
#  'структура',
#  'из',
#  'badges_trophies',
#  'интересный',
#  'особенность',
#  'являться',
#  'также',
#  'возможность',
#  'они',
#  'контроль',
#  'выдать',
#  'трофей',
#  'определённый',
#  'пользователь',
#  'вне',
#  'очередь',
#  'или',
#  'выдать',
#  'некий',
#  'особенный',
#  'трофей',
#  'без',
#  'определённый',
#  'критерий',
#  'конкретный',
#  'пользователь',
#  'за',
#  'особый',
#  'заслуга',
#  'можно',
#  'посмотреть',
#  'весь',
#  'пользователь',
#  'обладатель_трофей',
#  'можно',
#  'посмотреть',
#  'иконка_трофей',
#  'такой',
#  'образ',
#  'система',
#  'позволять',
#  'создавать',
#  'сложный',
#  'структура',
#  'для',
#  'реализация',
#  'геймификация',
#  'на',
#  'форум',
#  'вопрос',
#  'упираться_только_фантазия',
#  'для',
#  'создание',
#  'трофей',
#  'соответствующий',
#  'графический',
#  'оформление',
#  'иконка_трофей',
#  'подразумеваться',
#  'что',
#  'иконка_трофей',
#  'должный',
#  'быть',
#  'выдержать',
#  'единый',
#  'стиль',
#  'выглядеть_привлекательно',
#  'на',
#  'изображение',
#  'выше',
#  'можно',
#  'видеть',
#  'следующий',
#  'тестовый_черновой',
#  'система',
#  'бейдж_poster',
#  'тип_step-by-step',
#  'трофей_основать',
#  'на',
#  'критерий',
#  'количество',
#  'пост',
#  'соответствующий',
#  'возрастать',
#  'ценность_бейдж',
#  'favorite',
#  'тип_step-by-step',
#  'трофей_основать',
#  'на',
#  'критерий',
#  'количество_лайковый',
#  'соответствующий',
#  'возрастать',
#  'ценность_бейдж',
#  'cool_pleskian',
#  'тип',
#  'hidden_трофей',
#  'за',
#  'привязка',
#  'аккаунт',
#  'соцсеть',
#  'за',
#  'достижение',
#  'ratio',
#  'отношение',
#  'количество_лайковый',
#  'количество',
#  'пост',
#  'до',
#  'определённый',
#  'критерий',
#  'уровень',
#  'трофей',
#  'the_most',
#  'useful_бейдж',
#  'years',
#  'of',
#  'service',
#  'тип_step-by-step',
#  'трофей_основать',
#  'на',
#  'критерий',
#  'количество',
#  'день',
#  'момент',
#  'регистрация',
#  'на',
#  'форум',
#  'соответствующий',
#  'возрастать',
#  'ценность',
#  'дополнительно',
#  'нужно',
#  'упомянуть',
#  'следующий',
#  'технический',
#  'деталь',
#  'трофей',
#  'они',
#  'уровень',
#  'level_points',
#  'подсчитываться',
#  'для',
#  'пользователь',
#  'на',
#  'основа',
#  'срабатывание',
#  'соответствующий_crontask',
#  'который',
#  'при',
#  'желание',
#  'можно',
#  'запустить',
#  'вручную',
#  'система',
#  'с',
#  'сторона',
#  'обычный',
#  'пользователь',
#  'форум',
#  'после',
#  'тот',
#  'как',
#  'система',
#  'трофей',
#  'настроить',
#  'запустить',
#  'с',
#  'сторона',
#  'пользователь',
#  'форум',
#  'она',
#  'видный',
#  'вот',
#  'так',
#  'на',
#  'главное',
#  'меню',
#  'форум',
#  'появляться',
#  'таб_badges',
#  'собственный',
#  'таба_leaderboard',
#  'latest_awarded',
#  'профиль',
#  'каждый',
#  'пользователь',
#  'форум',
#  'так',
#  'же',
#  'появляться',
#  'отдельный',
#  'таб_badges',
#  'где',
#  'видный',
#  'он',
#  'заслуга',
#  'при',
#  'это',
#  'пользователь',
#  'мочь',
#  'сам',
#  'определить',
#  'какой',
#  'трофей',
#  'он',
#  'мочь',
#  'разместить',
#  'под',
#  'свой',
#  'аватара_форумный',
#  'пост',
#  'тред',
#  'пост',
#  'ваш',
#  'заслуга',
#  'быть',
#  'видный',
#  'вот',
#  'так',
#  'при',
#  'это',
#  'количество',
#  'позволить',
#  'для',
#  'показ',
#  'трофей',
#  'определяться',
#  'уровень',
#  'пользователь',
#  'level_points',
#  'зависеть',
#  'от',
#  'настройка',
#  'плагин',
#  'master_badge',
#  'чем',
#  'быть',
#  'сказать',
#  'выше',
#  'факт',
#  'получение',
#  'каждый',
#  'новое',
#  'трофей',
#  'пользователь',
#  'увидеть',
#  'вид',
#  'соответствующий',
#  'alert',
#  'верхний',
#  'право',
#  'угол_форума.ый',
#  'провокационность',
#  'результат',
#  'технический',
#  'вопрос',
#  'реализация',
#  'безусловно',
#  'важный',
#  'но',
#  'не',
#  'менее',
#  'важный',
#  'часть',
#  'система',
#  'наполнение',
#  'создать',
#  'запоминаться_креативный',
#  'яркий',
#  'иконка_трофей',
#  'не',
#  'менее_зажигательный',
#  'описание',
#  'очень',
#  'нетривиальный',
#  'задача',
#  'как',
#  'вызвать',
#  'острый',
#  'желание',
#  'пользователь',
#  'получить',
#  'тот',
#  'или',
#  'иной',
#  'трофей',
#  'путём',
#  'он',
#  'визуализация_вербализация',
#  'тема',
#  'отдельный',
#  'исследование',
#  'сказать',
#  'лишь',
#  'что',
#  'изрядный_доля',
#  'геймерский',
#  'опыт_озорство',
#  'даже',
#  'здоровый_провокационность',
#  'тут',
#  'просто',
#  'необходимый',
#  'при',
#  'это',
#  'важный',
#  'не',
#  'перейти',
#  'некоторый',
#  'грань',
#  'чтобы',
#  'оставаться',
#  'рамка_политкорректность',
#  'религиозный_расовый',
#  'терпимость_особенно',
#  'это',
#  'важный',
#  'на',
#  'форум_многонациональный',
#  'многоконфессиональный_состав',
#  'сообщество',
#  'как',
#  'небольшой',
#  'пример',
#  'такой',
#  'подход',
#  'мочь',
#  'привести',
#  'пара',
#  'трофей',
#  'наш',
#  'форум',
#  'когда',
#  'зарегистрировать',
#  'пользователь',
#  'заходить',
#  'на',
#  'форум',
#  'из',
#  'результат',
#  'поиск',
#  'google',
#  'он',
#  'получать',
#  'трофей_lmgtfy',
#  'let',
#  'me',
#  'google',
#  'this',
#  'for',
#  'you',
#  'иметь',
#  'описание',
#  'you_know',
#  'the',
#  'forum_has',
#  'its_own',
#  'search',
#  'right',
#  'иконка',
#  'вид',
#  'блиц_из_мультик',
#  'зверополис.ести',
#  'пользователь',
#  'включить',
#  'для',
#  'себя',
#  'двухфакторный_авторизация',
#  'то',
#  'он',
#  'получить',
#  'трофей_better',
#  'safe_than',
#  'sorry',
#  'описание',
#  'enabled_two-factor',
#  'authentication_because',
#  'why',
#  'not',
#  'иконка',
#  'защищать_профилактический',
#  'резиновый',
#  'изделие',
#  'подобный',
#  'подход',
#  'как',
#  'правило',
#  'вызывать',
#  'позитивный',
#  'реакция',
#  'сообщество',
#  'особенно',
#  'когда',
#  'такой',
#  'трофей',
#  'сделать',
#  'скрытый_вручаться',
#  'пользователь',
#  'неожиданно',
#  'для',
#  'они',
#  'результат',
#  'внедрение',
#  'этот',
#  'реализация',
#  'геймификация',
#  'точка_зрение',
#  'заявить',
#  'начало',
#  'статья',
#  'цель',
#  'говорить',
#  'пока',
#  'рано',
#  'но',
#  'тенденция',
#  'устойчивый',
#  'рост',
#  'активность',
#  'на',
#  'форум',
#  'заметный',
#  'сейчас',
#  'после',
#  'пара',
#  'месяц',
#  'с',
#  'время',
#  'запуск',
#  'система',
#  'сложно',
#  'оценить',
#  'доля',
#  'геймификация',
#  'это',
#  'но',
#  'по',
#  'мера',
#  'накопление',
#  'статистический',
#  'дать',
#  'влияние',
#  'можно',
#  'быть',
#  'попробовать',
#  'оценить',
#  'более',
#  'детально',
#  'если',
#  'вы',
#  'есть',
#  'опыт',
#  'по',
#  'внедрение',
#  'оценка',
#  'использование',
#  'система',
#  'геймификация_профильный',
#  'сообщество',
#  'делиться',
#  'пожалуйста',
#  'комментарий']

# %% [markdown]
# ### Тематическое моделирование в gensim

# %% [markdown]
# Для моделей нужно сделать словарь.

# %%
dictinary = gensim.corpora.Dictionary(ngrammed_texts)

# %%
dictinary.filter_extremes(no_above=0.25, no_below=25)
dictinary.compactify()

# %%
print(dictinary)
# Out:
# Dictionary(5737 unique tokens: ['примечание', 'ежедневно', 'семь', 'фокус', 'подразделение']...)

# %% [markdown]
# Преобразуем наши тексты в мешки слов.

# %%
corpus = [dictinary.doc2bow(text) for text in texts]
# если текстов много, то тут может быть генератор

# %%
lda = gensim.models.LdaMulticore(corpus, 250, id2word=dictinary, passes=5) # если поддерживается многопоточность
# lsi = gensim.models.LdaModel(200, id2word=dictinary, passes=5)
# Out:
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %% [markdown]
# Посмотрим на топики.

# %%
lda.print_topics(num_topics=-1)[122]
# Out:
# (122,
#  '0.017*"двигатель" + 0.014*"ракета" + 0.013*"аппарат" + 0.013*"спутник" + 0.010*"запуск" + 0.010*"космический" + 0.010*"ступень" + 0.010*"орбита" + 0.010*"полёт" + 0.009*"корабль"')

# %%
lda.print_topics(num_topics=-1)[0]
# Out:
# (0,
#  '0.017*"безопасность" + 0.016*"защита" + 0.012*"пароль" + 0.012*"атака" + 0.007*"security" + 0.007*"google" + 0.007*"уязвимость" + 0.005*"эксплуатация" + 0.005*"скрипт" + 0.005*"доступ"')

# %%
lda.print_topics(num_topics=-1)[242]
# Out:
# (242,
#  '0.031*"процессор" + 0.019*"видеокарта" + 0.014*"память" + 0.012*"производительность" + 0.010*"игра" + 0.009*"nvidia" + 0.009*"fps" + 0.009*"железо" + 0.008*"архитектура" + 0.008*"intel"')

# %% [markdown]
# Ещё есть штука для визуализации.

# %%
pyLDAvis.enable_notebook()

# %%
pyLDAvis.gensim.prepare(lda, corpus, dictinary)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# Можно посмотреть метрики.

# %%
import numpy as np

# %%
lda.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -74.77953844734222

# %%
coherence_model_lda = gensim.models.CoherenceModel(model=lda, 
                                                   texts=texts, 
                                                   dictionary=dictinary, coherence='c_v')

# %%
topics = []
for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

# %%
coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictinary, coherence='c_v')

# %%
coherence_model_lda.get_coherence()
# Out:
# 0.4472107961290014

# %%
# модель с tfidf
tfidf = gensim.models.TfidfModel(corpus, id2word=dictinary)
corpus = tfidf[corpus]

# %%
lda = gensim.models.LdaMulticore(corpus, 250, id2word=dictinary, passes=5)
# Out:
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\gensim\models\ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)

# %%
lda.print_topics(num_topics=-1)[122]
# Out:
# (122,
#  '0.048*"смартфон" + 0.034*"аккумулятор" + 0.023*"дисплей" + 0.020*"телефон" + 0.016*"розетка" + 0.015*"крышка" + 0.012*"батарея" + 0.012*"оснастить" + 0.011*"батарейка" + 0.011*"гаджет"')

# %%
lda.print_topics(num_topics=-1)[0]
# Out:
# (0,
#  '0.006*"flash" + 0.005*"герой" + 0.005*"днк" + 0.005*"пыль" + 0.004*"виджет" + 0.004*"бэкап" + 0.003*"in" + 0.003*"вселенная" + 0.003*"автомобильный" + 0.002*"память"')

# %%
lda.print_topics(num_topics=-1)[242]
# Out:
# (242,
#  '0.022*"мастер" + 0.015*"след" + 0.005*"сенсорный" + 0.005*"length" + 0.004*"лазер" + 0.004*"луна" + 0.004*"local" + 0.004*"поверхность" + 0.003*"skype" + 0.003*"машина"')

# %%
lda.log_perplexity(corpus[:2000], total_docs=100)
# Out:
# -346.4470521550176

# %%
coherence_model_lda = gensim.models.CoherenceModel(model=lda, 
                                                   texts=texts, 
                                                   dictionary=dictinary, coherence='c_v')

# %%
topics = []
for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

# %%
coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictinary, coherence='c_v')

# %%
coherence_model_lda.get_coherence()
# Out:
# 0.34835088966629985

# %%
### После добавления модели tfidf упали обе метрики perplexity и coherence.

# %% [markdown]
# ### Разложение матриц в sklearn

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pandas as pd

# %% [markdown]
# Sklearn принимает на вход строки, поэтому склеим наши списки.

# %%
stexts = [' '.join(text) for text in texts]

# %% [markdown]
# Сделаем матрицу слова-документы с помощью TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(max_features=25000, min_df=5, max_df=0.3, lowercase=False)
X = vectorizer.fit_transform(stexts)
# Out:
# C:\Users\Eolain\Anaconda3\envs\mllecture\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %% [markdown]
# Разложим её.

# %%
model = NMF(n_components=30)

# %%
model.fit(X)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=30, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0)

# %%
def get_nmf_topics(model, n_top_words):
    
    #id слов.
    feat_names = vectorizer.get_feature_names()
    
    word_dict = {};
    for i in range(30):
        
        #топ n слов для темы.
        words_ids = model.components_[i].argsort()[:-n_top_words - 1:-1]
        words = [feat_names[key] for key in words_ids]
        word_dict['Topic #' + '{:02d}'.format(i+1)] = words;
    
    return pd.DataFrame(word_dict);

# %%
get_nmf_topics(model, 10)
# Out:
#      Topic #01 Topic #02 Topic #03    Topic #04 Topic #05   Topic #06  \
# 0           ты        gt      игра  космический    объект        сеть
# 1      продукт        lt     игрок      спутник  значение      трафик
# 2    сотрудник       div   игровой       орбита   элемент       связь
# 3       бизнес     class    играть       ракета      блок          ip
# 4       клиент      this        vr         марс     метод    оператор
# 5  программист      name  персонаж      аппарат     класс    интернет
# 6     менеджер     props     steam        земля    строка  устройство
# 7         опыт    return     unity         луна       int         dpi
# 8           да       std  геймплей         наса      файл       канал
# 9       деньга      html    движок        полёт  алгоритм       адрес
#
#      Topic #07   Topic #08  Topic #09 Topic #10    ...            Topic #21  \
# 0       камера          js       сайт      файл    ...                 язык
# 1   устройство       react   страница    docker    ...     программирование
# 2     смартфон         css    реклама       php    ...                  php
# 3  аккумулятор  javascript     клиент      sudo    ...          программист
# 4      телефон     angular    контент     nginx    ...               лекция
# 5      дисплей         веб    браузер      http    ...                 java
# 6           гб         vue     письмо    сервер    ...              перевод
# 7        экран     браузер      домен       etc    ...            программа
# 8       xiaomi   компонент  рекламный    скрипт    ...               python
# 9        видео         dom     google       usr    ...                 курс
#
#           Topic #22 Topic #23       Topic #24   Topic #25      Topic #26  \
# 0             книга    public           центр         бот          робот
# 1              часы      void            дата    telegram        ребёнок
# 2          каковать    string        облачный   сообщение     автомобиль
# 3   порекомендовать       new  инфраструктура    телеграм           lego
# 4  профессиональный   private          услуга         чат         датчик
# 5             каким     класс          облако         bot  робототехника
# 6      предпочитать     class    оборудование         api         машина
# 7          бумажный       int             цод  мессенджер       движение
# 8           слушать    static          сервис       канал    беспилотный
# 9              путь    return              ит     message           дрон
#
#     Topic #27   Topic #28     Topic #29 Topic #30
# 0       товар     windows          звук        if
# 1       рынок   microsoft        сигнал    return
# 2       рубль       linux       наушник  function
# 3  российский      studio     усилитель       amp
# 4      россия      visual       частота      null
# 5      скидка         net      звуковой       end
# 6     магазин       azure        музыка      self
# 7      страна     браузер     искажение      else
# 8        цена  обновление  акустический       var
# 9       налог      server    напряжение      this
#
# [10 rows x 30 columns]
