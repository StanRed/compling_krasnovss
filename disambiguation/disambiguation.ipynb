# %% [markdown]
# ## Tagger Comparison
#
# To compare the work of different POS-taggers I chose the following Python packages:
#
# * TreeTagger
# * pymystem3
# * pymorphy2
#
# Being a big fan of the legendary Russian punk-rock group "Король и Шут", I decided to take the first verse and chorus from the song "Свой среди чужих" to analyse it with the taggers.

# %%
from nltk.tokenize import word_tokenize
lyrics_raw = "Как злобно сверкают глаза маньяка, Он проклинает всех живых, Но невдомёк ему, однако, Что есть свой среди чужих! Леса и просёлки, деревья да ёлки, А в посёлке воют волки. Опять с ним кто-то хочет поиграть. Никого вокруг, только сердца стук, И во власти рук заточенный сук - его верный друг. Что-то здесь не так, будто рядом враг. Как свинец кулак, подруга луна, подай верный знак!"
lyrics = word_tokenize(lyrics_raw)

# %% [markdown]
# First comes **TreeTagger**. Looks nice and simple, but takes some time and provides only one interpretation for a token and no additional grammatical info except POS-tags. A few tokens weren't identified at all (*'просёлки', 'посёлки', 'ёлки'*), probably the problem relates to the use of the letter 'Ёё'.

# %%
import pprint
import treetaggerwrapper
tagger = treetaggerwrapper.TreeTagger(TAGLANG='ru')
tt_raw = tagger.tag_text(lyrics)
tt = treetaggerwrapper.make_tags(tt_raw)
pprint.pprint(tt)
# Out:
# [Tag(word='Как', pos='C', lemma='как'),
#  Tag(word='злобно', pos='R', lemma='злобно'),
#  Tag(word='сверкают', pos='Vmip3p-a-e', lemma='сверкать'),
#  Tag(word='глаза', pos='Ncmpan', lemma='глаз'),
#  Tag(word='маньяка', pos='Ncmsgy', lemma='маньяк'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='Он', pos='P-3msnn', lemma='он'),
#  Tag(word='проклинает', pos='Vmip3s-a-e', lemma='проклинает'),
#  Tag(word='всех', pos='P---pga', lemma='весь'),
#  Tag(word='живых', pos='Afpmpgf', lemma='живой'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='Но', pos='C', lemma='но'),
#  Tag(word='невдомёк', pos='Ncmsnn', lemma='невдомёк'),
#  Tag(word='ему', pos='P-3msdn', lemma='он'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='однако', pos='C', lemma='однако'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='Что', pos='P--nsnn', lemma='что'),
#  Tag(word='есть', pos='Vmip3s-a-e', lemma='быть'),
#  Tag(word='свой', pos='P--msaa', lemma='свой'),
#  Tag(word='среди', pos='Sp-g', lemma='среди'),
#  Tag(word='чужих', pos='Afpmpgf', lemma='чужой'),
#  Tag(word='!', pos='SENT', lemma='!'),
#  Tag(word='Леса', pos='Ncmpnn', lemma='лес'),
#  Tag(word='и', pos='C', lemma='и'),
#  Tag(word='просёлки', pos='Ncfpnn', lemma='просёлки'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='деревья', pos='Ncnpnn', lemma='дерево'),
#  Tag(word='да', pos='C', lemma='да'),
#  Tag(word='ёлки', pos='Ncfpnn', lemma='ёлки'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='А', pos='C', lemma='а'),
#  Tag(word='в', pos='Sp-l', lemma='в'),
#  Tag(word='посёлке', pos='Ncfsln', lemma='посёлке'),
#  Tag(word='воют', pos='Vmip3p-a-e', lemma='выть'),
#  Tag(word='волки', pos='Ncmpny', lemma='волк'),
#  Tag(word='.', pos='SENT', lemma='.'),
#  Tag(word='Опять', pos='R', lemma='опять'),
#  Tag(word='с', pos='Sp-i', lemma='с'),
#  Tag(word='ним', pos='P-3msin', lemma='он'),
#  Tag(word='кто-то', pos='Ncmsnn', lemma='кто-то'),
#  Tag(word='хочет', pos='Vmip3s-a-e', lemma='хотеть'),
#  Tag(word='поиграть', pos='Vmn----a-p', lemma='поиграть'),
#  Tag(word='.', pos='SENT', lemma='.'),
#  Tag(word='Никого', pos='P--msgn', lemma='никто'),
#  Tag(word='вокруг', pos='R', lemma='вокруг'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='только', pos='Q', lemma='только'),
#  Tag(word='сердца', pos='Ncnsgn', lemma='сердце'),
#  Tag(word='стук', pos='Ncmsnn', lemma='стук'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='И', pos='C', lemma='и'),
#  Tag(word='во', pos='Sp-l', lemma='во'),
#  Tag(word='власти', pos='Ncfsln', lemma='власть'),
#  Tag(word='рук', pos='Ncfpgn', lemma='рука'),
#  Tag(word='заточенный', pos='Vmps-smp-pa', lemma='заточить'),
#  Tag(word='сук', pos='Ncmsan', lemma='сук'),
#  Tag(word='-', pos='-', lemma='-'),
#  Tag(word='его', pos='P-----a', lemma='его'),
#  Tag(word='верный', pos='Afpmsnf', lemma='верный'),
#  Tag(word='друг', pos='Ncmsny', lemma='друг'),
#  Tag(word='.', pos='SENT', lemma='.'),
#  Tag(word='Что-то', pos='R', lemma='Что-то'),
#  Tag(word='здесь', pos='P-----r', lemma='здесь'),
#  Tag(word='не', pos='Q', lemma='не'),
#  Tag(word='так', pos='P-----r', lemma='так'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='будто', pos='C', lemma='будто'),
#  Tag(word='рядом', pos='R', lemma='рядом'),
#  Tag(word='враг', pos='Ncmsny', lemma='враг'),
#  Tag(word='.', pos='SENT', lemma='.'),
#  Tag(word='Как', pos='C', lemma='как'),
#  Tag(word='свинец', pos='Ncmsnn', lemma='свинец'),
#  Tag(word='кулак', pos='Ncmsan', lemma='кулак'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='подруга', pos='Ncfsny', lemma='подруга'),
#  Tag(word='луна', pos='Ncfsnn', lemma='луна'),
#  Tag(word=',', pos=',', lemma=','),
#  Tag(word='подай', pos='Vmm-2s-a-p', lemma='подать'),
#  Tag(word='верный', pos='Afpmsaf', lemma='верный'),
#  Tag(word='знак', pos='Ncmsan', lemma='знак'),
#  Tag(word='!', pos='SENT', lemma='!')]

# %% [markdown]
# Then **pymystem3** appears on the stage. It didn't strike me as a convenient tool for POS-tagging due to the user-unfriendly output structure, although several grammatical interpretations are given in some cases (I wish pymystem3 provided their probabilities...). The 'Ёё' problem is solved here as well as cases of disambiguation, that's a positive sign. But still... the whole output looks as bulky as an opera singer.

# %%
from pymystem3 import Mystem
m = Mystem()
import json
ms = json.dumps(m.analyze(lyrics_raw), ensure_ascii=False)
for i in ms.split('{"analysis": '):
    print(i)
# Out:
# [
# [{"gr": "ADVPRO=", "lex": "как"}], "text": "Как"}, {"text": " "},
# [{"gr": "ADV=", "lex": "злобно"}], "text": "злобно"}, {"text": " "},
# [{"gr": "V,несов,нп=непрош,мн,изъяв,3-л", "lex": "сверкать"}], "text": "сверкают"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,мн|род,ед|им,мн)", "lex": "глаз"}], "text": "глаза"}, {"text": " "},
# [{"gr": "S,муж,од=(вин,ед|род,ед)", "lex": "маньяк"}], "text": "маньяка"}, {"text": ", "},
# [{"gr": "SPRO,ед,3-л,муж=им", "lex": "он"}], "text": "Он"}, {"text": " "},
# [{"gr": "V=непрош,ед,изъяв,3-л,несов,пе", "lex": "проклинать"}], "text": "проклинает"}, {"text": " "},
# [{"gr": "SPRO,мн=(пр|вин|род)", "lex": "все"}], "text": "всех"}, {"text": " "},
# [{"gr": "A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)", "lex": "живой"}], "text": "живых"}, {"text": ", "},
# [{"gr": "CONJ=", "lex": "но"}], "text": "Но"}, {"text": " "},
# [{"gr": "ADV,прдк=", "lex": "невдомек"}], "text": "невдомёк"}, {"text": " "},
# [{"gr": "SPRO,ед,3-л,муж=дат", "lex": "он"}], "text": "ему"}, {"text": ", "},
# [{"gr": "CONJ=", "lex": "однако"}], "text": "однако"}, {"text": ", "},
# [{"gr": "SPRO,ед,сред,неод=(вин|им)", "lex": "что"}], "text": "Что"}, {"text": " "},
# [{"gr": "V,нп=(непрош,ед,изъяв,3-л,несов|непрош,мн,изъяв,3-л,несов|наст,мн,изъяв,1-л,несов|наст,ед,изъяв,1-л,несов|наст,мн,изъяв,2-л,несов|наст,ед,изъяв,2-л,несов|наст,мн,изъяв,3-л,несов|наст,ед,изъяв,3-л,несов)", "lex": "быть"}], "text": "есть"}, {"text": " "},
# [{"gr": "APRO=(вин,ед,муж,неод|им,ед,муж)", "lex": "свой"}], "text": "свой"}, {"text": " "},
# [{"gr": "PR=", "lex": "среди"}], "text": "среди"}, {"text": " "},
# [{"gr": "A,полн=(пр,мн|род,мн|вин,мн,од)", "lex": "чужой"}], "text": "чужих"}, {"text": "! "},
# [{"gr": "S,муж,неод=(вин,мн|род,ед|им,мн)", "lex": "лес"}], "text": "Леса"}, {"text": " "},
# [{"gr": "CONJ=", "lex": "и"}], "text": "и"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,мн|им,мн)", "lex": "проселок"}], "text": "просёлки"}, {"text": ", "},
# [{"gr": "S,сред,неод=(вин,мн|им,мн)", "lex": "дерево"}], "text": "деревья"}, {"text": " "},
# [{"gr": "CONJ=", "lex": "да"}], "text": "да"}, {"text": " "},
# [{"gr": "S,жен,неод=(вин,мн|род,ед|им,мн)", "lex": "елка"}], "text": "ёлки"}, {"text": ", "},
# [{"gr": "CONJ=", "lex": "а"}], "text": "А"}, {"text": " "},
# [{"gr": "PR=", "lex": "в"}], "text": "в"}, {"text": " "},
# [{"gr": "S,муж,неод=пр,ед", "lex": "поселок"}], "text": "посёлке"}, {"text": " "},
# [{"gr": "V,несов,нп=непрош,мн,изъяв,3-л", "lex": "выть"}], "text": "воют"}, {"text": " "},
# [{"gr": "S,муж,од=им,мн", "lex": "волк"}], "text": "волки"}, {"text": ". "},
# [{"gr": "ADV=", "lex": "опять"}], "text": "Опять"}, {"text": " "},
# [{"gr": "PR=", "lex": "с"}], "text": "с"}, {"text": " "},
# [{"gr": "SPRO,ед,3-л,муж=твор", "lex": "он"}], "text": "ним"}, {"text": " "},
# [{"gr": "SPRO,ед,муж,од=им", "lex": "кто-то"}], "text": "кто-то"}, {"text": " "},
# [{"gr": "V,несов,пе=непрош,ед,изъяв,3-л", "lex": "хотеть"}], "text": "хочет"}, {"text": " "},
# [{"gr": "V,сов,пе=инф", "lex": "поиграть"}], "text": "поиграть"}, {"text": ". "},
# [{"gr": "SPRO,ед,муж,од=(вин|род)", "lex": "никто"}], "text": "Никого"}, {"text": " "},
# [{"gr": "PR=", "lex": "вокруг"}], "text": "вокруг"}, {"text": ", "},
# [{"gr": "PART=", "lex": "только"}], "text": "только"}, {"text": " "},
# [{"gr": "S,сред,неод=(вин,мн|род,ед|им,мн)", "lex": "сердце"}], "text": "сердца"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,ед|им,ед)", "lex": "стук"}], "text": "стук"}, {"text": ", "},
# [{"gr": "CONJ=", "lex": "и"}], "text": "И"}, {"text": " "},
# [{"gr": "PR=", "lex": "во"}], "text": "во"}, {"text": " "},
# [{"gr": "S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)", "lex": "власть"}], "text": "власти"}, {"text": " "},
# [{"gr": "S,жен,неод=род,мн", "lex": "рука"}], "text": "рук"}, {"text": " "},
# [{"gr": "V,сов,пе=(прош,вин,ед,прич,полн,муж,страд,неод|прош,им,ед,прич,полн,муж,страд)", "lex": "заточить"}], "text": "заточенный"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,ед|им,ед)", "lex": "сук"}], "text": "сук"}, {"text": " - "},
# [{"gr": "APRO=(пр,мн|дат,мн|род,мн|твор,мн|им,мн|им,ед,жен|вин,ед,муж,од|род,ед,муж|род,ед,сред|вин,ед,сред|им,ед,сред|пр,ед,жен|дат,ед,жен|род,ед,жен|твор,ед,жен|пр,ед,муж|пр,ед,сред|дат,ед,муж|дат,ед,сред|вин,ед,жен|вин,мн,неод|вин,ед,муж,неод|им,ед,муж|твор,ед,муж|твор,ед,сред|вин,мн,од|пр,мн,сред|вин,мн,сред|дат,мн,сред|род,мн,сред|твор,мн,сред|им,мн,сред|пр,мн,муж|вин,мн,муж|вин,ед,муж|дат,мн,муж)", "lex": "его"}], "text": "его"}, {"text": " "},
# [{"gr": "A=(вин,ед,полн,муж,неод|им,ед,полн,муж)", "lex": "верный"}], "text": "верный"}, {"text": " "},
# [{"gr": "S,муж,од=им,ед", "lex": "друг"}], "text": "друг"}, {"text": ". "},
# [{"gr": "SPRO,ед,сред,неод=(вин|им)", "lex": "что-то"}], "text": "Что-то"}, {"text": " "},
# [{"gr": "ADVPRO=", "lex": "здесь"}], "text": "здесь"}, {"text": " "},
# [{"gr": "PART=", "lex": "не"}], "text": "не"}, {"text": " "},
# [{"gr": "ADVPRO=", "lex": "так"}], "text": "так"}, {"text": ", "},
# [{"gr": "CONJ=", "lex": "будто"}], "text": "будто"}, {"text": " "},
# [{"gr": "ADV=", "lex": "рядом"}], "text": "рядом"}, {"text": " "},
# [{"gr": "S,муж,од=им,ед", "lex": "враг"}], "text": "враг"}, {"text": ". "},
# [{"gr": "CONJ=", "lex": "как"}], "text": "Как"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,ед|им,ед)", "lex": "свинец"}], "text": "свинец"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,ед|им,ед)", "lex": "кулак"}], "text": "кулак"}, {"text": ", "},
# [{"gr": "S,жен,од=им,ед", "lex": "подруга"}], "text": "подруга"}, {"text": " "},
# [{"gr": "S,жен,неод=им,ед", "lex": "луна"}], "text": "луна"}, {"text": ", "},
# [{"gr": "V,пе=ед,пов,2-л,сов", "lex": "подавать"}], "text": "подай"}, {"text": " "},
# [{"gr": "A=(вин,ед,полн,муж,неод|им,ед,полн,муж)", "lex": "верный"}], "text": "верный"}, {"text": " "},
# [{"gr": "S,муж,неод=(вин,ед|им,ед)", "lex": "знак"}], "text": "знак"}, {"text": "!"}, {"text": "\n"}]

# %% [markdown]
# Finally, let's look at **pymorphy2**. The first thing to be noticed here is multiple interpretations for almost every input token. They are ranked by probability scores, the treat I find quite useful for a wide range of researches. The output structure (imho) is relatively more readable in comparison with the previous package, taking into account the possibility to filter the output by probability values.

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
for i in lyrics:
    print(morph.parse(i),'\n')
# Out:
# [Parse(word='как', tag=OpencorporaTag('CONJ'), normal_form='как', score=0.875, methods_stack=((<DictionaryAnalyzer>, 'как', 1673, 0),)), Parse(word='как', tag=OpencorporaTag('ADVB,Ques'), normal_form='как', score=0.09375, methods_stack=((<DictionaryAnalyzer>, 'как', 1674, 0),)), Parse(word='как', tag=OpencorporaTag('PRCL'), normal_form='как', score=0.03125, methods_stack=((<DictionaryAnalyzer>, 'как', 22, 0),))]
#
# [Parse(word='злобно', tag=OpencorporaTag('ADVB'), normal_form='злобно', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'злобно', 3, 0),)), Parse(word='злобно', tag=OpencorporaTag('ADJS,Qual neut,sing'), normal_form='злобный', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'злобно', 12, 29),))]
#
# [Parse(word='сверкают', tag=OpencorporaTag('VERB,impf,intr plur,3per,pres,indc'), normal_form='сверкать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'сверкают', 15, 6),))]
#
# [Parse(word='глаза', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='глаз', score=0.882352, methods_stack=((<DictionaryAnalyzer>, 'глаза', 1140, 1),)), Parse(word='глаза', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='глаз', score=0.058823, methods_stack=((<DictionaryAnalyzer>, 'глаза', 1140, 7),)), Parse(word='глаза', tag=OpencorporaTag('NOUN,inan,masc plur,accs'), normal_form='глаз', score=0.058823, methods_stack=((<DictionaryAnalyzer>, 'глаза', 1140, 10),))]
#
# [Parse(word='маньяка', tag=OpencorporaTag('NOUN,anim,masc sing,gent'), normal_form='маньяк', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'маньяка', 2, 1),)), Parse(word='маньяка', tag=OpencorporaTag('NOUN,anim,masc sing,accs'), normal_form='маньяк', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'маньяка', 2, 3),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='он', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,nomn'), normal_form='он', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'он', 2208, 0),))]
#
# [Parse(word='проклинает', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='проклинать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'проклинает', 206, 5),))]
#
# [Parse(word='всех', tag=OpencorporaTag('ADJF,Apro plur,gent'), normal_form='весь', score=0.56132, methods_stack=((<DictionaryAnalyzer>, 'всех', 703, 21),)), Parse(word='всех', tag=OpencorporaTag('ADJF,Apro anim,plur,accs'), normal_form='весь', score=0.235849, methods_stack=((<DictionaryAnalyzer>, 'всех', 703, 24),)), Parse(word='всех', tag=OpencorporaTag('ADJF,Apro plur,loct'), normal_form='весь', score=0.20283, methods_stack=((<DictionaryAnalyzer>, 'всех', 703, 26),))]
#
# [Parse(word='живых', tag=OpencorporaTag('NOUN,anim,masc plur,gent'), normal_form='живой', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'живых', 461, 7),)), Parse(word='живых', tag=OpencorporaTag('NOUN,anim,masc plur,accs'), normal_form='живой', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'живых', 461, 9),)), Parse(word='живых', tag=OpencorporaTag('NOUN,anim,masc plur,loct'), normal_form='живой', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'живых', 461, 11),)), Parse(word='живых', tag=OpencorporaTag('ADJF,Qual plur,gent'), normal_form='живой', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'живых', 1162, 21),)), Parse(word='живых', tag=OpencorporaTag('ADJF,Qual anim,plur,accs'), normal_form='живой', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'живых', 1162, 23),)), Parse(word='живых', tag=OpencorporaTag('ADJF,Qual plur,loct'), normal_form='живой', score=0.16666666666666666, methods_stack=((<DictionaryAnalyzer>, 'живых', 1162, 26),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='но', tag=OpencorporaTag('CONJ'), normal_form='но', score=0.998721, methods_stack=((<DictionaryAnalyzer>, 'но', 20, 0),)), Parse(word='но', tag=OpencorporaTag('INTJ'), normal_form='но', score=0.001278, methods_stack=((<DictionaryAnalyzer>, 'но', 21, 0),))]
#
# [Parse(word='невдомёк', tag=OpencorporaTag('PRED,pres'), normal_form='невдомёк', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'невдомёк', 242, 0),))]
#
# [Parse(word='ему', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,datv'), normal_form='он', score=0.857142, methods_stack=((<DictionaryAnalyzer>, 'ему', 2208, 3),)), Parse(word='ему', tag=OpencorporaTag('NPRO,neut,3per,Anph sing,datv'), normal_form='оно', score=0.142857, methods_stack=((<DictionaryAnalyzer>, 'ему', 2211, 3),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='однако', tag=OpencorporaTag('CONJ,Prnt'), normal_form='однако', score=0.987124, methods_stack=((<DictionaryAnalyzer>, 'однако', 2200, 0),)), Parse(word='однако', tag=OpencorporaTag('INTJ'), normal_form='однако', score=0.012875, methods_stack=((<DictionaryAnalyzer>, 'однако', 21, 0),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='что', tag=OpencorporaTag('CONJ'), normal_form='что', score=0.791044, methods_stack=((<DictionaryAnalyzer>, 'что', 3046, 0),)), Parse(word='что', tag=OpencorporaTag('NPRO,neut sing,accs'), normal_form='что', score=0.089552, methods_stack=((<DictionaryAnalyzer>, 'что', 3047, 3),)), Parse(word='что', tag=OpencorporaTag('NPRO,neut sing,nomn'), normal_form='что', score=0.074626, methods_stack=((<DictionaryAnalyzer>, 'что', 3047, 0),)), Parse(word='что', tag=OpencorporaTag('PRCL'), normal_form='что', score=0.02985, methods_stack=((<DictionaryAnalyzer>, 'что', 22, 0),)), Parse(word='что', tag=OpencorporaTag('ADVB,Ques'), normal_form='что', score=0.014925, methods_stack=((<DictionaryAnalyzer>, 'что', 1130, 0),))]
#
# [Parse(word='есть', tag=OpencorporaTag('INTJ'), normal_form='есть', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'есть', 21, 0),)), Parse(word='есть', tag=OpencorporaTag('VERB,impf,intr sing,3per,pres,indc'), normal_form='быть', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'есть', 587, 1),)), Parse(word='есть', tag=OpencorporaTag('VERB,impf,intr plur,3per,pres,indc'), normal_form='быть', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'есть', 587, 3),)), Parse(word='есть', tag=OpencorporaTag('INFN,impf,tran'), normal_form='есть', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'есть', 1383, 0),))]
#
# [Parse(word='свой', tag=OpencorporaTag('ADJF,Apro,Anph inan,masc,sing,accs'), normal_form='свой', score=0.818181, methods_stack=((<DictionaryAnalyzer>, 'свой', 2737, 3),)), Parse(word='свой', tag=OpencorporaTag('ADJF,Apro,Anph masc,sing,nomn'), normal_form='свой', score=0.181818, methods_stack=((<DictionaryAnalyzer>, 'свой', 2737, 0),))]
#
# [Parse(word='среди', tag=OpencorporaTag('PREP'), normal_form='среди', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'среди', 24, 0),))]
#
# [Parse(word='чужих', tag=OpencorporaTag('NOUN,inan,neut plur,gent'), normal_form='чужое', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'чужих', 576, 7),)), Parse(word='чужих', tag=OpencorporaTag('NOUN,inan,neut plur,loct'), normal_form='чужое', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'чужих', 576, 11),)), Parse(word='чужих', tag=OpencorporaTag('ADJF,Subx plur,gent'), normal_form='чужой', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'чужих', 3055, 21),)), Parse(word='чужих', tag=OpencorporaTag('ADJF,Subx anim,plur,accs'), normal_form='чужой', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'чужих', 3055, 23),)), Parse(word='чужих', tag=OpencorporaTag('ADJF,Subx plur,loct'), normal_form='чужой', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'чужих', 3055, 26),))]
#
# [Parse(word='!', tag=OpencorporaTag('PNCT'), normal_form='!', score=1.0, methods_stack=((<PunctuationAnalyzer>, '!'),))]
#
# [Parse(word='леса', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='леса', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'леса', 55, 0),)), Parse(word='леса', tag=OpencorporaTag('NOUN,inan,masc sing,gent'), normal_form='лес', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'леса', 1314, 1),)), Parse(word='леса', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='лес', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'леса', 1314, 8),)), Parse(word='леса', tag=OpencorporaTag('NOUN,inan,masc plur,accs'), normal_form='лес', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'леса', 1314, 11),))]
#
# [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)), Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)), Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),))]
#
# [Parse(word='просёлки', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='просёлок', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'просёлки', 139, 6),)), Parse(word='просёлки', tag=OpencorporaTag('NOUN,inan,masc plur,accs'), normal_form='просёлок', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'просёлки', 139, 9),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='деревья', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='дерево', score=0.75, methods_stack=((<DictionaryAnalyzer>, 'деревья', 1270, 7),)), Parse(word='деревья', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='дерево', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'деревья', 1270, 13),))]
#
# [Parse(word='да', tag=OpencorporaTag('PRCL'), normal_form='да', score=0.581081, methods_stack=((<DictionaryAnalyzer>, 'да', 22, 0),)), Parse(word='да', tag=OpencorporaTag('CONJ'), normal_form='да', score=0.364864, methods_stack=((<DictionaryAnalyzer>, 'да', 20, 0),)), Parse(word='да', tag=OpencorporaTag('INTJ'), normal_form='да', score=0.054054, methods_stack=((<DictionaryAnalyzer>, 'да', 21, 0),))]
#
# [Parse(word='ёлки', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='ёлка', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'ёлки', 8, 1),)), Parse(word='ёлки', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='ёлка', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'ёлки', 8, 7),)), Parse(word='ёлки', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='ёлка', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'ёлки', 8, 10),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='а', tag=OpencorporaTag('CONJ'), normal_form='а', score=0.996696, methods_stack=((<DictionaryAnalyzer>, 'а', 20, 0),)), Parse(word='а', tag=OpencorporaTag('INTJ'), normal_form='а', score=0.002477, methods_stack=((<DictionaryAnalyzer>, 'а', 21, 0),)), Parse(word='а', tag=OpencorporaTag('PRCL'), normal_form='а', score=0.000825, methods_stack=((<DictionaryAnalyzer>, 'а', 22, 0),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,nomn'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,gent'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,datv'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,accs'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,ablt'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,loct'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,nomn'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,gent'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,datv'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,accs'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,ablt'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,loct'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,nomn'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,gent'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,datv'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,accs'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,ablt'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Patr,Fixd,Abbr,Init sing,loct'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,nomn'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,gent'), normal_form='а', score=0.0, methods_stack=((<AbbreviatedPatronymicAnalyzer>, 'А'),)), Parse(word='а', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Patr,Fixd,Abbr,Init sing,datv'), normal_form='а', score=0.0, m ...
#
# [Parse(word='в', tag=OpencorporaTag('PREP'), normal_form='в', score=0.999764, methods_stack=((<DictionaryAnalyzer>, 'в', 375, 0),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 20),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 21),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 22),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 23),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 24),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr sing,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 25),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,nomn'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 26),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,gent'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 27),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,datv'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 28),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,accs'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 29),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,ablt'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 30),)), Parse(word='в', tag=OpencorporaTag('NOUN,inan,masc,Fixd,Abbr plur,loct'), normal_form='век', score=1.9e-05, methods_stack=((<DictionaryAnalyzer>, 'в', 666, 31),))]
#
# [Parse(word='посёлке', tag=OpencorporaTag('NOUN,inan,masc sing,loct'), normal_form='посёлок', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'посёлке', 139, 5),))]
#
# [Parse(word='воют', tag=OpencorporaTag('VERB,impf,intr plur,3per,pres,indc'), normal_form='выть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'воют', 1103, 6),))]
#
# [Parse(word='волки', tag=OpencorporaTag('NOUN,anim,masc plur,nomn'), normal_form='волк', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'волки', 2, 6),)), Parse(word='волки', tag=OpencorporaTag('NOUN,inan,masc plur,nomn'), normal_form='волк', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'волки', 19, 6),)), Parse(word='волки', tag=OpencorporaTag('NOUN,inan,masc plur,accs'), normal_form='волк', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'волки', 19, 9),))]
#
# [Parse(word='.', tag=OpencorporaTag('PNCT'), normal_form='.', score=1.0, methods_stack=((<PunctuationAnalyzer>, '.'),))]
#
# [Parse(word='опять', tag=OpencorporaTag('ADVB'), normal_form='опять', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'опять', 3, 0),))]
#
# [Parse(word='с', tag=OpencorporaTag('PREP'), normal_form='с', score=0.998363, methods_stack=((<DictionaryAnalyzer>, 'с', 375, 0),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,nomn'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 13),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,gent'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 14),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,datv'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 15),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,accs'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 16),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,ablt'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 17),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr sing,loct'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 18),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,nomn'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 19),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,gent'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 20),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,datv'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 21),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,accs'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 22),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,ablt'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 23),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,femn,Fixd,Abbr plur,loct'), normal_form='секунда', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2747, 24),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,nomn'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 12),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,gent'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 13),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,datv'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 14),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,accs'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 15),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,ablt'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 16),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr sing,loct'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 17),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,nomn'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 18),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,gent'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 19),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,datv'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 20),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,accs'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 21),)), Parse(word='с', tag=OpencorporaTag('NOUN,inan,neut,Fixd,Abbr plur,ablt'), normal_form='село', score=6.8e-05, methods_stack=((<DictionaryAnalyzer>, 'с', 2748, 22),)), Parse(word='с ...
#
# [Parse(word='ним', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,ablt,Af-p'), normal_form='он', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'ним', 2208, 8),)), Parse(word='ним', tag=OpencorporaTag('NPRO,3per,Anph plur,datv,Af-p'), normal_form='они', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'ним', 2210, 4),)), Parse(word='ним', tag=OpencorporaTag('NPRO,neut,3per,Anph sing,ablt,Af-p'), normal_form='оно', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'ним', 2211, 8),))]
#
# [Parse(word='кто-то', tag=OpencorporaTag('NPRO,masc sing,nomn'), normal_form='кто-то', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'кто-то', 1822, 0),))]
#
# [Parse(word='хочет', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='хотеть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'хочет', 2999, 5),))]
#
# [Parse(word='поиграть', tag=OpencorporaTag('INFN,perf,tran'), normal_form='поиграть', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'поиграть', 614, 0),))]
#
# [Parse(word='.', tag=OpencorporaTag('PNCT'), normal_form='.', score=1.0, methods_stack=((<PunctuationAnalyzer>, '.'),))]
#
# [Parse(word='никого', tag=OpencorporaTag('NPRO sing,accs'), normal_form='никто', score=0.625, methods_stack=((<DictionaryAnalyzer>, 'никого', 2121, 3),)), Parse(word='никого', tag=OpencorporaTag('NPRO sing,gent'), normal_form='никто', score=0.375, methods_stack=((<DictionaryAnalyzer>, 'никого', 2121, 1),))]
#
# [Parse(word='вокруг', tag=OpencorporaTag('ADVB'), normal_form='вокруг', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'вокруг', 3, 0),)), Parse(word='вокруг', tag=OpencorporaTag('PREP'), normal_form='вокруг', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'вокруг', 24, 0),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='только', tag=OpencorporaTag('PRCL'), normal_form='только', score=0.928571, methods_stack=((<DictionaryAnalyzer>, 'только', 2892, 0),)), Parse(word='только', tag=OpencorporaTag('CONJ'), normal_form='только', score=0.071428, methods_stack=((<DictionaryAnalyzer>, 'только', 2891, 0),))]
#
# [Parse(word='сердца', tag=OpencorporaTag('NOUN,inan,neut sing,gent'), normal_form='сердце', score=0.90909, methods_stack=((<DictionaryAnalyzer>, 'сердца', 474, 1),)), Parse(word='сердца', tag=OpencorporaTag('NOUN,inan,neut plur,nomn'), normal_form='сердце', score=0.045454, methods_stack=((<DictionaryAnalyzer>, 'сердца', 474, 6),)), Parse(word='сердца', tag=OpencorporaTag('NOUN,inan,neut plur,accs'), normal_form='сердце', score=0.045454, methods_stack=((<DictionaryAnalyzer>, 'сердца', 474, 10),))]
#
# [Parse(word='стук', tag=OpencorporaTag('INTJ'), normal_form='стук', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стук', 21, 0),)), Parse(word='стук', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='стук', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стук', 330, 0),)), Parse(word='стук', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='стук', score=0.3333333333333333, methods_stack=((<DictionaryAnalyzer>, 'стук', 330, 4),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='и', tag=OpencorporaTag('CONJ'), normal_form='и', score=0.997671, methods_stack=((<DictionaryAnalyzer>, 'и', 20, 0),)), Parse(word='и', tag=OpencorporaTag('INTJ'), normal_form='и', score=0.000436, methods_stack=((<DictionaryAnalyzer>, 'и', 21, 0),)), Parse(word='и', tag=OpencorporaTag('PRCL'), normal_form='и', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 22, 0),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 12),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 13),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 14),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 15),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 16),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr sing,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 17),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,nomn'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 18),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,gent'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 19),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,datv'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 20),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,accs'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 21),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,ablt'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 22),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Fixd,Abbr plur,loct'), normal_form='исполняющий', score=0.000145, methods_stack=((<DictionaryAnalyzer>, 'и', 3144, 23),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,nomn'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,gent'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,datv'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,accs'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,ablt'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Name,Fixd,Abbr,Init sing,loct'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,nomn'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,gent'), normal_form='и', score=0.0, methods_stack=((<AbbreviatedFirstNameAnalyzer>, 'И'),)), Parse(word='и', tag=OpencorporaTag('NOUN,anim,femn,Sgtm,Name,Fixd,Abbr,Init sing,datv'), normal_form='и', score=0.0, methods_s ...
#
# [Parse(word='во', tag=OpencorporaTag('PREP Vpre'), normal_form='в', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'во', 375, 1),))]
#
# [Parse(word='власти', tag=OpencorporaTag('NOUN,inan,femn sing,gent'), normal_form='власть', score=0.882352, methods_stack=((<DictionaryAnalyzer>, 'власти', 13, 1),)), Parse(word='власти', tag=OpencorporaTag('NOUN,inan,femn sing,datv'), normal_form='власть', score=0.058823, methods_stack=((<DictionaryAnalyzer>, 'власти', 13, 2),)), Parse(word='власти', tag=OpencorporaTag('NOUN,inan,femn sing,loct'), normal_form='власть', score=0.019607, methods_stack=((<DictionaryAnalyzer>, 'власти', 13, 5),)), Parse(word='власти', tag=OpencorporaTag('NOUN,inan,femn plur,nomn'), normal_form='власть', score=0.019607, methods_stack=((<DictionaryAnalyzer>, 'власти', 13, 6),)), Parse(word='власти', tag=OpencorporaTag('NOUN,inan,femn plur,accs'), normal_form='власть', score=0.019607, methods_stack=((<DictionaryAnalyzer>, 'власти', 13, 9),))]
#
# [Parse(word='рук', tag=OpencorporaTag('NOUN,inan,femn plur,gent'), normal_form='рука', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'рук', 43, 8),))]
#
# [Parse(word='заточенный', tag=OpencorporaTag('PRTF,perf,tran,past,pssv masc,sing,nomn'), normal_form='заточить', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'заточенный', 951, 43),)), Parse(word='заточенный', tag=OpencorporaTag('PRTF,perf,tran,past,pssv inan,masc,sing,accs'), normal_form='заточить', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'заточенный', 951, 51),)), Parse(word='заточённый', tag=OpencorporaTag('PRTF,perf,tran,past,pssv masc,sing,nomn,Infr'), normal_form='заточить', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'заточённый', 951, 42),)), Parse(word='заточённый', tag=OpencorporaTag('PRTF,perf,tran,past,pssv inan,masc,sing,accs,Infr'), normal_form='заточить', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'заточённый', 951, 50),))]
#
# [Parse(word='сук', tag=OpencorporaTag('NOUN,anim,femn plur,gent'), normal_form='сука', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'сук', 403, 8),)), Parse(word='сук', tag=OpencorporaTag('NOUN,anim,femn plur,accs'), normal_form='сука', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'сук', 403, 10),)), Parse(word='сук', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='сук', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'сук', 2852, 0),)), Parse(word='сук', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='сук', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'сук', 2852, 3),))]
#
# [Parse(word='-', tag=OpencorporaTag('PNCT'), normal_form='-', score=1.0, methods_stack=((<PunctuationAnalyzer>, '-'),))]
#
# [Parse(word='его', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,accs'), normal_form='он', score=0.234042, methods_stack=((<DictionaryAnalyzer>, 'его', 2208, 5),)), Parse(word='его', tag=OpencorporaTag('NPRO,neut,3per,Anph sing,gent'), normal_form='оно', score=0.063829, methods_stack=((<DictionaryAnalyzer>, 'его', 2211, 1),)), Parse(word='его', tag=OpencorporaTag('NPRO,neut,3per,Anph sing,accs'), normal_form='оно', score=0.063829, methods_stack=((<DictionaryAnalyzer>, 'его', 2211, 5),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,gent'), normal_form='его', score=0.042553, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 7),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,gent'), normal_form='его', score=0.042553, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 13),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,nomn'), normal_form='его', score=0.042553, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 18),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph plur,datv'), normal_form='его', score=0.042553, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 20),)), Parse(word='его', tag=OpencorporaTag('NPRO,masc,3per,Anph sing,gent'), normal_form='он', score=0.042553, methods_stack=((<DictionaryAnalyzer>, 'его', 2208, 1),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,nomn'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 0),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,gent'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 1),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,datv'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 2),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,accs'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 3),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,ablt'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 4),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph masc,sing,loct'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 5),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,nomn'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 6),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,datv'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 8),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,accs'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 9),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,ablt'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 10),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph femn,sing,loct'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 11),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,nomn'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 12),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,datv'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 14),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,accs'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 15),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,ablt'), normal_form='его', score=0.021276, methods_stack=((<DictionaryAnalyzer>, 'его', 1377, 16),)), Parse(word='его', tag=OpencorporaTag('ADJF,Fixd,Apro,Anph neut,sing,loct'), normal_form='его', score=0.021276, methods_stack=((<Diction ...
#
# [Parse(word='верный', tag=OpencorporaTag('ADJF,Qual masc,sing,nomn'), normal_form='верный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'верный', 214, 0),)), Parse(word='верный', tag=OpencorporaTag('ADJF,Qual inan,masc,sing,accs'), normal_form='верный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'верный', 214, 4),))]
#
# [Parse(word='друг', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='друг', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'друг', 1361, 0),))]
#
# [Parse(word='.', tag=OpencorporaTag('PNCT'), normal_form='.', score=1.0, methods_stack=((<PunctuationAnalyzer>, '.'),))]
#
# [Parse(word='что-то', tag=OpencorporaTag('NPRO,neut sing,nomn'), normal_form='что-то', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'что-то', 3050, 0),)), Parse(word='что-то', tag=OpencorporaTag('ADVB'), normal_form='что-то', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'что-то', 3, 0),)), Parse(word='что-то', tag=OpencorporaTag('NPRO,neut sing,accs'), normal_form='что-то', score=0.25, methods_stack=((<DictionaryAnalyzer>, 'что-то', 3050, 3),))]
#
# [Parse(word='здесь', tag=OpencorporaTag('ADVB,Prdx'), normal_form='здесь', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'здесь', 385, 0),))]
#
# [Parse(word='не', tag=OpencorporaTag('PRCL'), normal_form='не', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'не', 22, 0),))]
#
# [Parse(word='так', tag=OpencorporaTag('CONJ'), normal_form='так', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'так', 20, 0),)), Parse(word='так', tag=OpencorporaTag('ADVB,Dmns'), normal_form='так', score=0.388888, methods_stack=((<DictionaryAnalyzer>, 'так', 2872, 0),)), Parse(word='так', tag=OpencorporaTag('PRCL'), normal_form='так', score=0.111111, methods_stack=((<DictionaryAnalyzer>, 'так', 22, 0),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='будто', tag=OpencorporaTag('CONJ'), normal_form='будто', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'будто', 20, 0),)), Parse(word='будто', tag=OpencorporaTag('PRCL'), normal_form='будто', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'будто', 22, 0),))]
#
# [Parse(word='рядом', tag=OpencorporaTag('NOUN,inan,masc sing,ablt'), normal_form='ряд', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'рядом', 111, 4),)), Parse(word='рядом', tag=OpencorporaTag('ADVB,Prdx'), normal_form='рядом', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'рядом', 385, 0),))]
#
# [Parse(word='враг', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='враг', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'враг', 2, 0),))]
#
# [Parse(word='.', tag=OpencorporaTag('PNCT'), normal_form='.', score=1.0, methods_stack=((<PunctuationAnalyzer>, '.'),))]
#
# [Parse(word='как', tag=OpencorporaTag('CONJ'), normal_form='как', score=0.875, methods_stack=((<DictionaryAnalyzer>, 'как', 1673, 0),)), Parse(word='как', tag=OpencorporaTag('ADVB,Ques'), normal_form='как', score=0.09375, methods_stack=((<DictionaryAnalyzer>, 'как', 1674, 0),)), Parse(word='как', tag=OpencorporaTag('PRCL'), normal_form='как', score=0.03125, methods_stack=((<DictionaryAnalyzer>, 'как', 22, 0),))]
#
# [Parse(word='свинец', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='свинец', score=0.666666, methods_stack=((<DictionaryAnalyzer>, 'свинец', 277, 3),)), Parse(word='свинец', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='свинец', score=0.333333, methods_stack=((<DictionaryAnalyzer>, 'свинец', 277, 0),))]
#
# [Parse(word='кулак', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='кулак', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'кулак', 2, 0),)), Parse(word='кулак', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='кулак', score=0.4, methods_stack=((<DictionaryAnalyzer>, 'кулак', 19, 3),)), Parse(word='кулак', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='кулак', score=0.2, methods_stack=((<DictionaryAnalyzer>, 'кулак', 19, 0),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='подруга', tag=OpencorporaTag('NOUN,anim,femn sing,nomn'), normal_form='подруга', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'подруга', 403, 0),))]
#
# [Parse(word='луна', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='луна', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'луна', 55, 0),))]
#
# [Parse(word=',', tag=OpencorporaTag('PNCT'), normal_form=',', score=1.0, methods_stack=((<PunctuationAnalyzer>, ','),))]
#
# [Parse(word='подай', tag=OpencorporaTag('VERB,perf,tran sing,impr,excl'), normal_form='подать', score=1.0, methods_stack=((<DictionaryAnalyzer>, 'подай', 843, 13),))]
#
# [Parse(word='верный', tag=OpencorporaTag('ADJF,Qual masc,sing,nomn'), normal_form='верный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'верный', 214, 0),)), Parse(word='верный', tag=OpencorporaTag('ADJF,Qual inan,masc,sing,accs'), normal_form='верный', score=0.5, methods_stack=((<DictionaryAnalyzer>, 'верный', 214, 4),))]
#
# [Parse(word='знак', tag=OpencorporaTag('NOUN,inan,masc sing,nomn'), normal_form='знак', score=0.555555, methods_stack=((<DictionaryAnalyzer>, 'знак', 19, 0),)), Parse(word='знак', tag=OpencorporaTag('NOUN,inan,masc sing,accs'), normal_form='знак', score=0.444444, methods_stack=((<DictionaryAnalyzer>, 'знак', 19, 3),))]
#
# [Parse(word='!', tag=OpencorporaTag('PNCT'), normal_form='!', score=1.0, methods_stack=((<PunctuationAnalyzer>, '!'),))]

# %% [markdown]
# Speaking about the speed of the packages, pymystem3 is pedaling in the Peloton behind pymorphy2 while TreeTagger is pulling up the rear.
#
# In terms of accuracy, all the three taggers show quite sustainable results, but TreeTagger deals with the task slightly worse. In my future work, I'd rather rely on pymorphy2, bearing in mind "fine tuning" of its parameters, probability scores and the suitability for working with Russian texts.
